# %%
import pandas as pd
from scipy import stats

# %%
unet_spleen_baseline_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='unet_spleen_baseline.csv').columns)]
resunet_spleen_baseline_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='resunet_spleen_baseline.csv').columns)]
experiment_1_spleen_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='experiment_1_spleen.csv').columns)]
experiment_2_spleen_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='experiment_2_spleen.csv').columns)]
experiment_3_spleen_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='experiment_3_spleen.csv').columns)]
experiment_4_spleen_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='experiment_4_spleen.csv').columns)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [23], line 2
#       1 unet_spleen_baseline_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='unet_spleen_baseline.csv').columns)]
# ----> 2 resunet_spleen_baseline_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='resunet_spleen_baseline.csv').columns)]
#       3 experiment_1_spleen_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='experiment_1_spleen.csv').columns)]
#       4 experiment_2_spleen_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='experiment_2_spleen.csv').columns)]
#
# Cell In [23], line 2, in <listcomp>(.0)
#       1 unet_spleen_baseline_dsc = [float(dsc) for dsc in list(pd.read_csv(filepath_or_buffer='unet_spleen_baseline.csv').columns)]
# ...

# %%
experiment_1_spleen_dsc
# Out:
# ['0.9580104947090149',
#  '0.9567373394966125',
#  '0.9480536580085754',
#  '0.9495253562927246',
#  '0.954079806804657',
#  '0.9544429183006287',
#  '0.9540943503379822',
#  '0.9541085362434387',
#  '0.9561815857887268',
#  '0.9553048014640808',
#  '0.9536301493644714',
#  '0.9528775811195374',
#  '0.9545736908912659',
#  '0.9538464546203613',
#  '0.950276792049408',
#  '0.9536932110786438',
#  '0.9543881416320801',
#  '0.9535632729530334',
#  '0.957611083984375',
#  '0.9572997093200684',
#  '0.952486515045166',
#  '0.9527179598808289',
#  '0.9477856755256653',
#  '0.9463620185852051',
#  '0.9506637454032898',
#  '0.9503157734870911',
#  '0.9436433911323547',
#  '0.9378644824028015',
#  '0.9540693163871765',
#  '0.9541088938713074',
#  '0.9525146484375',
#  '0.9534777998924255',
#  '0.9550320506095886',
#  '0.9528995156288147',
#  '0.952186107635498',
#  '0.9516698718070984',
#  '0.951999843120575',
#  '0.9528574347496033',
#  '0.9531407356262207',
#  '0.9525406360626221',
# ...

# %%
group1 = unet_spleen_baseline_dsc
group2 = resunet_spleen_baseline_dsc
group3 = experiment_1_spleen_dsc
group4 = experiment_2_spleen_dsc
group5 = experiment_3_spleen_dsc
group6 = experiment_4_spleen_dsc

# %%
stats.friedmanchisquare(group1, group2, group3, group4, group5, group6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 stats.friedmanchisquare(group1, group2, group3, group4, group5, group6)
#
# File ~/miniconda3/envs/qnas/lib/python3.8/site-packages/scipy/stats/stats.py:7962, in friedmanchisquare(*args)
#    7960 # Rank data
#    7961 data = np.vstack(args).T
# -> 7962 data = data.astype(float)
#    7963 for i in range(len(data)):
#    7964     data[i] = rankdata(data[i])
#
# ValueError: could not convert string to float: '0.9563475251197815.1'
